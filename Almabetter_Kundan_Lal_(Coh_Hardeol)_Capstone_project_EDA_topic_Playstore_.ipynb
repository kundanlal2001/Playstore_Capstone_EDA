# %% [markdown]
# <a href="https://colab.research.google.com/github/kundanlal2001/Playstore_Capstone_EDA/blob/main/Almabetter_Kundan_Lal_(Coh_Hardeol)_Capstone_project_EDA_topic_Playstore_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path ='/content/drive/MyDrive/Datasets/Play _Store _Data.csv'
playstoredf = pd.read_csv(file_path)

# %%
# Data cleaning done on Installs column
playstoredf['Installs']=playstoredf['Installs'].apply(lambda x:x.replace('+',''))
playstoredf['Installs']=playstoredf['Installs'].apply(lambda x:x.replace(',',''))
playstoredf=playstoredf.drop(10472)
playstoredf['Installs']=playstoredf['Installs'].astype(dtype=int)

# %%
#data cleaning done on Size column
playstoredf['Size'] = playstoredf['Size'].str.replace('M',"000")
playstoredf['Size'] = playstoredf['Size'].str.replace('k',"")
playstoredf['Size'] = playstoredf['Size'].str.replace("1,000+","1000")
playstoredf['Size'] = playstoredf['Size'].str.replace('Varies with device',"0")
playstoredf['Size'] = playstoredf['Size'].astype(dtype=float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.

# %%
# data type conversion done on Reviews Column for study
playstoredf['Reviews'] = playstoredf['Reviews'].astype(dtype=int)

# %%
playstoredf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
# Applying mean function to replace all NaN values 
x= playstoredf["Rating"].mean()
playstoredf["Rating"].fillna(x , inplace = True)

# %%
# To look at the information of all columns and its data types
playstoredf.info()
# As after applying mean function values were coming to 4 decimal places in Rating column so converting it to 1 decimal place
psdf = playstoredf.round(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.2+ MB

# %%
# selecting Category ,Rating , Reviews & Installs columns for "ART & Design "category only 
table1 = psdf.loc[ 0: 48, ['App','Category','Rating','Reviews','Installs','Size']]

# %%
plt.rcParams['figure.figsize'] = (22,6)
table1.plot.bar(x= 'App' , y = 'Rating');
plt.title('Most Rated apps amongst all apps in ART AND DESIGN CATEGORY')
plt.ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')

# %%
plt.rcParams['figure.figsize'] = (22,6)
table1.plot.bar(x= 'App' , y = 'Installs');
plt.title('Most Installed apps amongst all apps in ART AND DESIGN CATEGORY')
plt.ylabel('Total Installations')
# Out:
# Text(0, 0.5, 'Total Installations')

# %%
# selecting Category ,Rating & Review columns for "AUTO_AND_VEHICLES "category only 
table2 = psdf.loc[ 49:98, ['App','Category','Rating','Reviews','Installs','Size']]

# %%
table2
# Out:
#                                                   App           Category  \
# 49                        Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
# 50                               Real Tractor Farming  AUTO_AND_VEHICLES
# 51                    Ultimate F1 Racing Championship  AUTO_AND_VEHICLES
# 52                      Used Cars and Trucks for Sale  AUTO_AND_VEHICLES
# 53                           American Muscle Car Race  AUTO_AND_VEHICLES
# 54     Offroad Oil Tanker Driver Transport Truck 2019  AUTO_AND_VEHICLES
# 55  Tickets SDA 2018 and Exam from the State Traff...  AUTO_AND_VEHICLES
# 56                          Gas Prices (Germany only)  AUTO_AND_VEHICLES
# 57                         Extreme Rally Championship  AUTO_AND_VEHICLES
# 58                                  Restart Navigator  AUTO_AND_VEHICLES
# 59  REG - Check the regnumber, find information ab...  AUTO_AND_VEHICLES
# 60                                       CityBus Lviv  AUTO_AND_VEHICLES
# 61                     CDL Practice Test 2018 Edition  AUTO_AND_VEHICLES
# 62  ezETC (ETC balance inquiry, meter trial, real-...  AUTO_AND_VEHICLES
# 63                      Free VIN Report for Used Cars  AUTO_AND_VEHICLES
# 64              DMV Permit Practice Test 2018 Edition  AUTO_AND_VEHICLES
# 65                                  Check Vehicle Tax  AUTO_AND_VEHICLES
# 66                                   Used Cars Mexico  AUTO_AND_VEHICLES
# 67                                 Ulysse Speedometer  AUTO_AND_VEHICLES
# 68                                             REPUVE  AUTO_AND_VEHICLES
# 69                        Used cars for sale - Trovit  AUTO_AND_VEHICLES
# 70  Fines of the State Traffic Safety Inspectorate...  AUTO_AND_VEHICLES
# 71            SK Enca Direct Malls - Used Cars Search  AUTO_AND_VEHICLES
# 72      Android Auto - Maps, Media, Messaging & Voice  AUTO_AND_VEHICLES
# 73                                             PDD-UA  AUTO_AND_VEHICLES
# 74                         Tickets SDA 2019 + Exam RF  AUTO_AND_VEHICLES
# 75              Super Cars Wallpapers And Backgrounds  AUTO_AND_VEHICLES
# 76                  Police Lights, Sirens & Follow Me  AUTO_AND_VEHICLES
# 77               Police Detector (Speed Camera Radar)  AUTO_AND_VEHICLES
# 78                                Best Car Wallpapers  AUTO_AND_VEHICLES
# 79                            Tickets + PDA 2018 Exam  AUTO_AND_VEHICLES
# 80                              Pick Your Part Garage  AUTO_AND_VEHICLES
# 81                         PakWheels: Buy & Sell Cars  AUTO_AND_VEHICLES
# 82                                Supervision service  AUTO_AND_VEHICLES
# 83      Speed Camera Detector - Traffic & Speed Alert  AUTO_AND_VEHICLES
# 84        Used car search Goo net whole car Go to net  AUTO_AND_VEHICLES
# 85  CarMax – Cars for Sale: Search Used Car Inventory  AUTO_AND_VEHICLES
# 86                                    BEST CAR SOUNDS  AUTO_AND_VEHICLES
# 87                      RST - Sale of cars on the PCT  AUTO_AND_VEHICLES
# 88        AutoScout24 Switzerland – Find your new car  AUTO_AND_VEHICLES
# 89  Zona Azul Digital Fácil SP CET - OFFICIAL São ...  AUTO_AND_VEHICLES
# 90                                           SMS Park  AUTO_AND_VEHICLES
# 91                                            SKencar  AUTO_AND_VEHICLES
# 92                            Fuelio: Gas log & costs  AUTO_AND_VEHICLES
# 93                                         auto fines  AUTO_AND_VEHICLES
# 94  Used car is the first car - used car purchase,...  AUTO_AND_VEHICLES
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
#
#     Rating  Reviews  Installs     Size
# 49     4.2      367    100000  25000.0
# 50     4.0     1598   1000000  56000.0
# 51     3.8      284    100000  57000.0
# 52     4.6    17057   1000000      0.0
# 53     3.9      129    100000  35000.0
# 54     4.3      542    100000  33000.0
# 55     4.9    10479    100000  33000.0
# 56     4.4      805     50000      5.6
# 57     4.2      129    100000  54000.0
# 58     4.0     1403    100000    201.0
# 59     3.9     3971    100000      3.6
# 60     4.6      534     10000      5.7
# 61     4.9     7774    100000  17000.0
# 62     4.3    38846   1000000      8.6
# 63     4.6     2431    100000      2.4
# 64     4.9     6090    100000  27000.0
# 65     3.9      295     10000      2.7
# 66     4.0      190     50000      2.5
# 67     4.3    40211   5000000      0.0
# 68     3.9      356    100000      0.0
# 69     4.2    52530   5000000      7.0
# 70     4.8   116986   5000000  35000.0
# 71     3.6     1379    500000  16000.0
# 72     4.2   271920  10000000  16000.0
# 73     4.8      736    100000      0.0
# 74     4.8     7021    500000  17000.0
# 75     4.6      197     50000      3.4
# 76     4.5      737    100000      8.9
# 77     4.3     3574   1000000      3.9
# 78     4.5      994    100000      2.9
# 79     4.9   197136   1000000  38000.0
# 80     3.9      142     50000  32000.0
# 81     4.4    15168   1000000  37000.0
# 82     4.0     2155    500000  15000.0
# 83     4.3      138    100000      5.4
# 84     3.7     5414   1000000  18000.0
# 85     4.4    21777   1000000      0.0
# 86     4.3      348    100000  38000.0
# 87     3.2      250    100000      1.1
# 88     4.6    13372   1000000      0.0
# 89     4.6     7880    100000      0.0
# 90     4.5     3617    100000      7.9
# 91     3.7     4806   1000000  35000.0
# 92     4.6    65786   1000000      0.0
# 93     4.6    31433   1000000  17000.0
# 94     4.6     5097   1000000  19000.0
# 95     4.0     1754    500000  14000.0
# 96     4.4     2680    500000      2.2
# 97     4.0     1288    100000      4.5
# 98     4.7    18900    500000  17000.0

# %%
plt.rcParams['figure.figsize'] = (22,6)
table2.plot.bar(x= 'App' , y = 'Rating');
plt.title('Most Rated apps amongst all apps in AUTO_AND_VEHICLES')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
plt.rcParams['figure.figsize'] = (22,6)
table2.plot.bar(x= 'App' , y = 'Installs');
plt.title('Most Installed apps amongst all apps in AUTO AND VEHICLE CATEGORY')
plt.ylabel('Total Installations')
# Out:
# Text(0, 0.5, 'Total Installations')

# %%
# selecting Category ,Rating, Review ,Installs columns for "Communication  "category only 
table3 = psdf.loc[ 337:475, ['App','Category','Rating','Reviews','Installs','Size']]

# %%
table3
# Out:
#                                                App       Category  Rating  \
# 337                              Messenger for SMS  COMMUNICATION     4.3
# 338                   Google Chrome: Fast & Secure  COMMUNICATION     4.3
# 339          Messenger Lite: Free Calls & Messages  COMMUNICATION     4.4
# 340                                          Gmail  COMMUNICATION     4.3
# 341                                       Hangouts  COMMUNICATION     4.0
# ..                                             ...            ...     ...
# 471  JusTalk - Free Video Calls and Fun Video Chat  COMMUNICATION     4.6
# 472                   Glide - Video Chat Messenger  COMMUNICATION     4.3
# 473                   Talkray - Free Calls & Texts  COMMUNICATION     4.2
# 474                    LINE: Free Calls & Messages  COMMUNICATION     4.2
# 475                   KakaoTalk: Free Calls & Text  COMMUNICATION     4.3
#
#       Reviews    Installs     Size
# 337    125257    10000000  17000.0
# 338   9642995  1000000000      0.0
# 339   1429035   100000000      0.0
# 340   4604324  1000000000      0.0
# 341   3419249  1000000000      0.0
# ..        ...         ...      ...
# 471    191032     5000000  26000.0
# 472    350154    10000000      0.0
# 473    244863    10000000      0.0
# 474  10790289   500000000      0.0
# 475   2546527   100000000      0.0
#
# [139 rows x 6 columns]

# %%
plt.rcParams['figure.figsize'] = (25,6)
table3.plot.bar(x= 'App' , y = 'Rating');
plt.title('Most Rated apps amongst all apps in Communication category')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 128044 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 128044 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.rcParams['figure.figsize'] = (15,40)
table3.plot.barh(x= 'App' , y = 'Installs');
plt.title('Most Installed apps amongst all apps in Communication ')
plt.ylabel('Total Installations')
# Out:
# Text(0, 0.5, 'Total Installations')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 128044 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 128044 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Finding average rating Category wise
plt.rcParams['figure.figsize']=(20,5)
psdf4 = psdf.loc[ 0: , ['Category','Rating']]
psdf5 = psdf4.groupby('Category').mean('Rating')
psdf5.plot.bar();

# %%
#Finding average review Category wise
plt.rcParams['figure.figsize']=(20,5)
psdf6 = psdf.loc[ 0: , ['Category','Reviews']]
psdf7 = psdf6.groupby('Category').mean('Reviews')
psdf7.plot.bar();

# %%
# finding out Average size of app in each category of App, Category wise
plt.rcParams['figure.figsize']=(20,5)
psdf2 = psdf.loc[ 0: , ['Category','Size']]
psdf3 = psdf2.groupby('Category').mean('Size')
psdf3.plot.bar();

# %%
# finding out Average Installs of app in each category of App, Category wise
plt.rcParams['figure.figsize']=(18,10)
psdf9 = psdf.loc[ 0: , ['Category','Installs']]
psdf10 = psdf9.groupby('Category').mean('Installs')
psdf10.plot.barh();
